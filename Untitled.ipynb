# %%
pi
# Out:
# Matplotlib is building the font cache; this may take a moment.
# pi

# %%
numerical_approx(pi)
# Out:
# 3.14159265358979

# %%
pi
# Out:
# pi

# %%
circle()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [4], line 1
# ----> 1 circle()
#
# File /usr/lib/python3/dist-packages/sage/misc/decorators.py:657, in rename_keyword.__call__.<locals>.wrapper(*args, **kwds)
#     655         kwds[new_name] = kwds[old_name]
#     656         del kwds[old_name]
# --> 657 return func(*args, **kwds)
#
# File /usr/lib/python3/dist-packages/sage/misc/decorators.py:496, in options.__call__.<locals>.wrapper(*args, **kwds)
#     494     options['__original_opts'] = kwds
#     495 options.update(kwds)
# --> 496 return func(*args, **options)
#
# TypeError: circle() missing 2 required positional arguments: 'center' and 'radius'

# %%
plot(sqrt(4-x^2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
var('x y')
implicit_plot(y^2==4-x-x^2, (x,-2,2), (y,-2,2))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
integral(ln(x), x)
# Out:
# x*log(x) - x

# %%
var('z')
z = 2*pi
print(numerical_approx(z))
# Out:
# 6.28318530717959

# %%
p = random_prime(2**64)
q = random_prime(2**64)
n = p * q
factor(n)

# %%
p = random_prime(2**32)
q = random_prime(2**32)
n = p * q
factor(n)
# Out:
# Exiting Sage (CPU time 152m3.85s, Wall time 252m36.38s).
